# %%
a = [1,2,3,4,5]

print(type(a))
# Out:
# <class 'list'>

# %%
a.append(69)

print(a)
# Out:
# [1, 2, 3, 4, 5, 69]

# %%
print(a[5])
# Out:
# 69

# %%
del(a[4])
print(a)
# Out:
# [1, 2, 3, 4, 69]
