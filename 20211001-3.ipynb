# %%
a = {1,2,3}
print(a)
a.add(7)
print(a)
a.add(1)
print(len(a))
# Out:
# {1, 2, 3}
# {1, 2, 3, 7}
# 4

# %%
import random

lotto = set()
# print(type(lotto))

count=0
while len(lotto) < 6:
  lotto.add(random.randrange(1,46))
  count = count + 1

print(lotto)
print(count)
# Out:
# {1, 34, 3, 39, 15, 19}
# 6
